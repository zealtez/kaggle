# %%
import numpy as np
import pandas as pd
import sys
import os
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# Out:
# /home/tommy/program/lib/python3.6/site-packages/matplotlib/font_manager.py:279: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
sys.path
# Out:
# ['',
#  '/home/tommy/program/lib/python36.zip',
#  '/home/tommy/program/lib/python3.6',
#  '/home/tommy/program/lib/python3.6/lib-dynload',
#  '/home/tommy/program/lib/python3.6/site-packages',
#  '/home/tommy/program/lib/python3.6/site-packages/IPython/extensions',
#  '/home/tommy/.ipython']

# %%
rawdata = pd.read_csv('../../dataSet/beerDataSet/recipeData.csv',encoding = 'ISO-8859-1')

# %%
rawdata
# Out:
#        BeerID                                          Name  \
# 0           1                             Vanilla Cream Ale
# 1           2                   Southern Tier Pumking clone
# 2           3                   Zombie Dust Clone - EXTRACT
# 3           4                 Zombie Dust Clone - ALL GRAIN
# 4           5               Bakke Brygg Belgisk Blonde 50 l
# 5           6                  Sierra Nevada Pale Ale Clone
# 6           7      Russian River Pliny the Elder (original)
# 7           8  Spotted Clown (New Glarus Spotted Cow clone)
# 8           9                      Chocolate Vanilla Porter
# 9          10                            Mango Habanero IPA
# 10         11                     Bakke Brygg HveteIPA 25 L
# 11         12                               Hop Notch Clone
# 12         13                             Racer 5 IPA Clone
# 13         14                     Sam Adams Rebel IPA Clone
# 14         15                                     White IPA
# ...

# %%
rawdata.columns
# Out:
# Index(['BeerID', 'Name', 'URL', 'Style', 'StyleID', 'Size(L)', 'OG', 'FG',
#        'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity',
#        'Efficiency', 'MashThickness', 'SugarScale', 'BrewMethod', 'PitchRate',
#        'PrimaryTemp', 'PrimingMethod', 'PrimingAmount'],
#       dtype='object')
